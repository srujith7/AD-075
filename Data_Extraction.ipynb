# %% [markdown]
# <a href="https://colab.research.google.com/github/srujith7/AD-075/blob/main/Data_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyPDF2==3.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# The correct import statement for the PyPDF2 package is:
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
pdf = open("/content/file1pdf.pdf","rb")
pdf_reader = PyPDF2.pdfReader(pdf)
print(pdf_reader.numPages)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-b7b5d0d7b06d> in <cell line: 0>()
#       1 pdf = open("/content/file1pdf.pdf","rb")
# ----> 2 pdf_reader = PyPDF2.pdfReader(pdf)
#       3 print(pdf_reader.numPages)
#
# AttributeError: module 'PyPDF2' has no attribute 'pdfReader'

# %%
import nltk
nltk.download('stopwords')

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
pdf = open("/content/file1pdf.pdf","rb")
# Change 'pdfReader' to 'PdfFileReader' to match the import
pdf_reader = PyPDF2.PdfReader(pdf)
print(pdf_reader.pages)

# %%
pdf=open("/content/file1pdf.pdf","rb")
pdf_reader=PyPDF2.PdfReader(pdf)
print("number of pages:",len(pdf_reader.pages))
page=pdf_reader.pages[2]
print(page.extract_text())
pdf.close()
# Out:
# number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034    Table of Contents
#
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34............................................................................................................................. .............. 3
# Our gratitude  to the following  experts for their invaluable  insights and support: ............................  3
# We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# ...

# %%
pdf = open("file1pdf.pdf", "rb")

# %%
import PyPDF2, urllib, nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
wFile = urllib.request.urlopen('http://www.udri.org/pdf/02%20working%20paper%201.pdf')
pdfreader = PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
pageObj=pdfreader.pages[2]
page2=pageObj.extract_text()
#Cleaning the text
punctuations=['(',')',';',':','[',']',',','...','-' ]
pageObj=pdfreader.pages[2]
page2=pageObj.extract_text()
#Cleaning the text
punctuations=['(',')',';',':','[',']',',','...','-' ]
tokens=word_tokenize(page2)
stop_words=stopwords.words('english')
keywords=[word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
# ...

# %%
name_list = list()
check = ['Mr.', 'Mrs.', 'Ms.']
for idx, token in enumerate(tokens):
  # Change 'startwith' to 'startswith' to call the correct string method
  if token.startswith(tuple(check)) and idx < (len(tokens)-1):
    name_list.append(token + tokens[idx+1])
    name_list.append(token)
print(name_list)
# Out:
# ['Mr.Jagdish', 'Mr.', 'Mr.Dinesh', 'Mr.', 'Mr.Hiren', 'Mr.', 'Ms.Anita', 'Ms.', 'Mr.Prasad', 'Mr.']

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import docx

# %%
doc=open("/content/MODULE-1-Introduction to AWS (2).docx","rb")
document=docx.Document(doc)
print(document)

# %%
docu=" "
for para in document.paragraphs:
  docu+=para.text
print(docu)
# Out:
#  MODULE 1: Introduction to AWSBasic CRUD application – Create, Read, Update and Delete actions are applicable.The system in above snippet will be built step by step using “Amazon Management Console” and below are some quick details on the various services being used.Amazon VPC – application will be built on a private network called as “Amazon Virtual Private Cloud”.Amazon EC2 Instance – host the application backend code on “Amazon Elastic Compute Cloud” which is a service that essentially offers a virtual machine on AWS.Amazon RDS DB Instance/Amazon DynamoDB – employee data will be stored on this service offered by AWS named as “Amazon Relational Database Service” or “Amazon DynamoDB”.Amazon S3 – The images/photos of the employee’s will be stored using object storing AWS service named “Amazon Simple Storage Service” and it allows unlimited storage of any file type.Amazon CloudWatch -  used for monitoring the system setup and alert, in case of issues.ELB – we will need this service fo
# ...

# %%
for i in range(len(document.paragraphs)):
  print("The contents of PAragraph"+str(i)+"is:"+document.paragraphs[i].text+"\n")
# Out:
# The contents of PAragraph0is:MODULE 1: Introduction to AWS
#
# The contents of PAragraph1is:
#
# The contents of PAragraph2is:Basic CRUD application – Create, Read, Update and Delete actions are applicable.
#
# The contents of PAragraph3is:
#
# The contents of PAragraph4is:
#
# The contents of PAragraph5is:
#
# The contents of PAragraph6is:
#
# The contents of PAragraph7is:
#
# The contents of PAragraph8is:The system in above snippet will be built step by step using “Amazon Management Console” and below are some quick details on the various services being used.
#
# The contents of PAragraph9is:
#
# The contents of PAragraph10is:
#
# The contents of PAragraph11is:Amazon VPC – application will be built on a private network called as “Amazon Virtual Private Cloud”.
#
# The contents of PAragraph12is:
#
# ...
